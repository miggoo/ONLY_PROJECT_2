# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_file = "econ_data.csv"
#convert to df
data_df = pd.read_csv(csv_file, encoding='utf-8')
data_df
# Out:
#         ID  level_0  index                                            GeoName  \
# 0        0        0  32790  Winston-Salem, NC (Metropolitan Statistical Area)
# 1        1        1  32797  Winston-Salem, NC (Metropolitan Statistical Area)
# 2        2        2  32798  Winston-Salem, NC (Metropolitan Statistical Area)
# 3        3        3  32877   Worcester, MA-CT (Metropolitan Statistical Area)
# 4        4        4  32884   Worcester, MA-CT (Metropolitan Statistical Area)
# 5        5        5  32885   Worcester, MA-CT (Metropolitan Statistical Area)
# 6        6        6  32964         Yakima, WA (Metropolitan Statistical Area)
# 7        7        7  32971         Yakima, WA (Metropolitan Statistical Area)
# 8        8        8  32972         Yakima, WA (Metropolitan Statistical Area)
# 9        9        9  33051   York-Hanover, PA (Metropolitan Statistical Area)
# 10      10       10  33058   York-Hanover, PA (Metropolitan Statistical Area)
# ...

# %%
data_df = data_df.T.reset_index(); data_df[data_df.columns[::-1]]
# Out:
#                                                2258  \
# 0                                              2258
# 1                                              2258
# 2                                             98230
# 3   Walla Walla, WA (Metropolitan Statistical Area)
# 4                                                90
# 5             Private services-providing industries
# 6                                               923
# 7                                               979
# 8                                              1003
# 9                                              1019
# 10                                             1099
# 11                                             1027
# 12                                             1053
# 13                                             1103
# 14                                             1139
# 15                                             1225
# 16                                             1244
# ...
